# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Importing Data

# %%
# this is the file path to the main project folder
path = r'C:\Users\david\04-06-2024 Instacart Basket Analysis'

# %%
# orders_wrangled.csv dataframe
df_ords = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'orders_wrangled.csv'))

# %%
# products.csv dataframe
df_prods = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'products.csv'))

# %% [markdown]
# ## df_test practice

# %%
# create a dataframe
df_test = pd.DataFrame()

# %%
# create mixed type column
df_test['mix'] = ['a', 'b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
# check for mixed types
for col in df_test.columns.tolist():
  weird = (df_test[[col]].map(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix

# %% [markdown]
# ## Finding missing values

# %%
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
# creates new dataframe without missing values
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %% [markdown]
# ## Checking for duplicates

# %%
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %% [markdown]
# ## Exercise 4.5

# %%
# Importing orders_wrangled

# this is the file path to the main project folder
path = r'C:\Users\david\04-06-2024 Instacart Basket Analysis'

# orders_wrangled.csv dataframe
df_ords = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'orders_wrangled.csv'))

# %% [markdown]
# ## Question 2

# %%
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_ordinal_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06          3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05          1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04          1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00          1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04          5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05          1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05          2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05          1.000000e+02
#
#        order_day_of_week  order_hour_of_day  days_since_prior_order
# count       3.421083e+06       3.421083e+06            3.214874e+06
# mean        2.776219e+00       1.345202e+01            1.111484e+01
# std         2.046829e+00       4.226088e+00            9.206737e+00
# ...

# %%
# looked up code to use describe without scientific notation
df_ords.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#           Unnamed: 0       order_id        user_id order_ordinal_number  \
# count  3421083.00000  3421083.00000  3421083.00000        3421083.00000
# mean   1710541.00000  1710542.00000   102978.20806             17.15486
# std     987581.73983   987581.73982    59533.71779             17.73316
# min          0.00000        1.00000        1.00000              1.00000
# 25%     855270.50000   855271.50000    51394.00000              5.00000
# 50%    1710541.00000  1710542.00000   102689.00000             11.00000
# 75%    2565811.50000  2565812.50000   154385.00000             23.00000
# max    3421082.00000  3421083.00000   206209.00000            100.00000
#
#       order_day_of_week order_hour_of_day days_since_prior_order
# count     3421083.00000     3421083.00000          3214874.00000
# mean            2.77622          13.45202               11.11484
# std             2.04683           4.22609                9.20674
# ...

# %% [markdown]
# First column is unamed. This should be labled the index column.
#
# Order day of week has a minimum of 0 and a maximum of 6. All 7 days of week are covered.
#
# Order hour of day has a minimum of 0 and a maximum of 23. All 24 hours of day are covered
#
# Days since prior order has a lower count than other columns, indicating missing values

# %% [markdown]
# ## Question 3

# %%
# check for mixed types
for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].map(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0:
    print (col)

# %% [markdown]
# No mixed-type data in any columns

# %% [markdown]
# ## Question 5

# %%
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# order_ordinal_number           0
# order_day_of_week              0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
df_dspo_missing = df_ords[df_ords['days_since_prior_order'].isnull() == True]

# %%
df_dspo_missing
# Out:
#          Unnamed: 0  order_id  user_id  order_ordinal_number  \
# 0                 0   2539329        1                     1
# 11               11   2168274        2                     1
# 26               26   1374495        3                     1
# 39               39   3343014        4                     1
# 45               45   2717275        5                     1
# ...             ...       ...      ...                   ...
# 3420930     3420930    969311   206205                     1
# 3420934     3420934   3189322   206206                     1
# 3421002     3421002   2166133   206207                     1
# 3421019     3421019   2227043   206208                     1
# 3421069     3421069   3154581   206209                     1
#
#          order_day_of_week  order_hour_of_day  days_since_prior_order
# 0                        2                  8                     NaN
# 11                       2                 11                     NaN
# ...

# %%
df_dspo_missing.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#           Unnamed: 0       order_id       user_id order_ordinal_number  \
# count   206209.00000   206209.00000  206209.00000         206209.00000
# mean   1712636.72965  1708461.83300  103105.00000              1.00000
# std     987481.63880   988129.90200   59527.55517              0.00000
# min          0.00000       20.00000       1.00000              1.00000
# 25%     857973.00000   850730.00000   51553.00000              1.00000
# 50%    1717068.00000  1706246.00000  103105.00000              1.00000
# 75%    2570518.00000  2564292.00000  154657.00000              1.00000
# max    3421069.00000  3421081.00000  206209.00000              1.00000
#
#       order_day_of_week order_hour_of_day days_since_prior_order
# count      206209.00000      206209.00000                0.00000
# mean            2.75412          13.62660                    nan
# std             2.07621           4.22377                    nan
# min             0.00000           0.00000                    nan
# ...

# %% [markdown]
# All missing data is associated with customers shopping for the very first time. This is shown by the order_ordinal_number column, with a min and max of 1. It is probably smartest to just create an additional column that shows if an order is a person's first or not.

# %% [markdown]
# ## Question 6

# %%
df_ords_clean = df_ords
df_ords_clean['first_order'] = df_ords_clean['days_since_prior_order'].isna()

# %%
df_ords_clean
# Out:
#          Unnamed: 0  order_id  user_id  order_ordinal_number  \
# 0                 0   2539329        1                     1
# 1                 1   2398795        1                     2
# 2                 2    473747        1                     3
# 3                 3   2254736        1                     4
# 4                 4    431534        1                     5
# ...             ...       ...      ...                   ...
# 3421078     3421078   2266710   206209                    10
# 3421079     3421079   1854736   206209                    11
# 3421080     3421080    626363   206209                    12
# 3421081     3421081   2977660   206209                    13
# 3421082     3421082    272231   206209                    14
#
#          order_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                        2                  8                     NaN
# 1                        3                  7                    15.0
# ...

# %% [markdown]
# ## Question 7

# %%
df_ords_dup = df_ords_clean[df_ords_clean.duplicated()]
df_ords_dup
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, order_ordinal_number, order_day_of_week, order_hour_of_day, days_since_prior_order, first_order]
# Index: []

# %% [markdown]
# Zero duplicate values.

# %% [markdown]
# ## Question 9

# %%
df_ords_clean[df_ords_clean['user_id'] == 1]
# Out:
#     Unnamed: 0  order_id  user_id  order_ordinal_number  order_day_of_week  \
# 0            0   2539329        1                     1                  2
# 1            1   2398795        1                     2                  3
# 2            2    473747        1                     3                  3
# 3            3   2254736        1                     4                  4
# 4            4    431534        1                     5                  4
# 5            5   3367565        1                     6                  2
# 6            6    550135        1                     7                  1
# 7            7   3108588        1                     8                  1
# 8            8   2295261        1                     9                  1
# 9            9   2550362        1                    10                  4
# 10          10   1187899        1                    11                  4
#
#     order_hour_of_day  days_since_prior_order  first_order
# ...

# %%
df_ords_clean.to_csv(os.path.join(path, 'Data', 'Prepared Data', 'orders_cleaned.csv'))

# %%
df_prods_clean_no_dups.to_csv(os.path.join(path, 'Data', 'Prepared Data', 'products_cleaned.csv'))
