# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Main Project Folder

# %%
path = r'C:\Users\david\04-06-2024 Instacart Basket Analysis'

# %% [markdown]
# ## Data Import

# %%
df_ords_prior = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_prior.csv'))

# %%
df_ords = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'orders_cleaned.csv'))

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_ordinal_number  \
# 0             0           0   2539329        1                     1
# 1             1           1   2398795        1                     2
# 2             2           2    473747        1                     3
# 3             3           3   2254736        1                     4
# 4             4           4    431534        1                     5
#
#    order_day_of_week  order_hour_of_day  days_since_prior_order  first_order
# 0                  2                  8                     NaN         True
# 1                  3                  7                    15.0        False
# 2                  3                 12                    21.0        False
# 3                  4                  7                    29.0        False
# 4                  4                 15                    28.0        False

# %%
df_ords.shape
# Out:
# (3421083, 9)

# %% [markdown]
# ## df_ords and df_ords_prior merge

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# ## Exercise 4.6

# %%
# Question 2
df_merged_large.to_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Question 3
df_orders_product_combined_check = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_combined.pkl'))
df_orders_product_combined_check.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_ordinal_number  \
# 0             0           0   2539329        1                     1
# 1             0           0   2539329        1                     1
# 2             0           0   2539329        1                     1
# 3             0           0   2539329        1                     1
# 4             0           0   2539329        1                     1
#
#    order_day_of_week  order_hour_of_day  days_since_prior_order  first_order  \
# 0                  2                  8                     NaN         True
# 1                  2                  8                     NaN         True
# 2                  2                  8                     NaN         True
# 3                  2                  8                     NaN         True
# 4                  2                  8                     NaN         True
#
#    product_id  add_to_cart_order  reordered _merge
# ...

# %%
# Question 4
df_orders_product_combined_check.shape
# 32434489 = 32434489
# Out:
# (32434489, 13)

# %%
df_prods = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'products_cleaned.csv'))

# %%
#5
df = df_merged_large.merge(df_prods, on = 'product_id')

# %%
df
# Out:
#           Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_ordinal_number  \
# 0                    0             0   2539329        1                     1
# 1                    1             1   2398795        1                     2
# 2                    2             2    473747        1                     3
# 3                    3             3   2254736        1                     4
# 4                    4             4    431534        1                     5
# ...                ...           ...       ...      ...                   ...
# 32404854       3360493       3360493   1320836   202557                    17
# 32404855       3360494       3360494     31526   202557                    18
# 32404856       3376038       3376038    758936   203436                     1
# 32404857       3376039       3376039   2745165   203436                     2
# 32404858       3408036       3408036   3093936   205420                     1
#
# ...

# %%
df[df['user_id'] == 1]
# Out:
#         Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_ordinal_number  \
# 0                  0             0   2539329        1                     1
# 1                  1             1   2398795        1                     2
# 2                  2             2    473747        1                     3
# 3                  3             3   2254736        1                     4
# 4                  4             4    431534        1                     5
# 5                  5             5   3367565        1                     6
# 6                  6             6    550135        1                     7
# 7                  7             7   3108588        1                     8
# 8                  8             8   2295261        1                     9
# 9                  9             9   2550362        1                    10
# 35791              0             0   2539329        1                     1
# ...

# %%
df1 = df[:1000000]

# %%
def price_label(row):
    if row['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices'] > 15:
        return 'High-range product'
    else:
        return 'Not enough data'

# %%
df1['prices'].max()
# Out:
# 14.8

# %%
df.to_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_combined.pkl'))
